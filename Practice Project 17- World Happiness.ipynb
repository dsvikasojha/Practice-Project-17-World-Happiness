# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
ds=pd.read_csv('happiness_score_dataset.csv')

# %%
ds.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
ds.tail(5)
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
ds.shape
# Out:
# (158, 12)

# %%
ds.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There are no null values in dataset

# %%
ds['Country'].unique()
# Out:
# array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada', 'Finland',
#        'Netherlands', 'Sweden', 'New Zealand', 'Australia', 'Israel',
#        'Costa Rica', 'Austria', 'Mexico', 'United States', 'Brazil',
#        'Luxembourg', 'Ireland', 'Belgium', 'United Arab Emirates',
#        'United Kingdom', 'Oman', 'Venezuela', 'Singapore', 'Panama',
#        'Germany', 'Chile', 'Qatar', 'France', 'Argentina',
#        'Czech Republic', 'Uruguay', 'Colombia', 'Thailand',
#        'Saudi Arabia', 'Spain', 'Malta', 'Taiwan', 'Kuwait', 'Suriname',
#        'Trinidad and Tobago', 'El Salvador', 'Guatemala', 'Uzbekistan',
#        'Slovakia', 'Japan', 'South Korea', 'Ecuador', 'Bahrain', 'Italy',
#        'Bolivia', 'Moldova', 'Paraguay', 'Kazakhstan', 'Slovenia',
#        'Lithuania', 'Nicaragua', 'Peru', 'Belarus', 'Poland', 'Malaysia',
#        'Croatia', 'Libya', 'Russia', 'Jamaica', 'North Cyprus', 'Cyprus',
# ...

# %%
sns.stripplot(x='Happiness Score',y='Region',data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Region'>

# %% [markdown]
# It can bee seen from above plot that the happyness score of Western Europe lies b/w 5-8, Middle East and North Africa
# lies b/w 3-7 and of Southern Asia lies b/w 3.5 to 5.2

# %%
i=ds['Country'][:15]
plt.figure(figsize=(10,10))
sns.scatterplot(x='Happiness Score',y='Economy (GDP per Capita)',hue=i,data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %% [markdown]
# It can be seen from above that the country with more GDP has more Happiness Score

# %%
i=ds['Country'][:15]
plt.figure(figsize=(10,10))
sns.scatterplot(x='Happiness Score',y='Family',hue=i,data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Family'>

# %%
i=ds['Country'][:15]
plt.figure(figsize=(10,10))
sns.scatterplot(x='Happiness Score',y='Health (Life Expectancy)',hue=i,data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Health (Life Expectancy)'>

# %%
i=ds['Country'][:15]
plt.figure(figsize=(10,10))
sns.scatterplot(x='Happiness Score',y='Freedom',hue=i,data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Freedom'>

# %% [markdown]
# It can be seen from above plot that the Countries which has higher freedom has more happiness score.

# %%
i=ds['Country'][:10]
plt.figure(figsize=(10,10))
sns.scatterplot(x='Happiness Score',y='Trust (Government Corruption)',hue=i,data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Trust (Government Corruption)'>

# %%
i=ds['Country'][:10]
plt.figure(figsize=(10,10))
sns.scatterplot(x='Happiness Score',y='Generosity',hue=i,data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Generosity'>

# %%
i=ds['Country'][:10]
plt.figure(figsize=(10,10))
sns.scatterplot(x='Happiness Score',y='Dystopia Residual',hue=i,data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Dystopia Residual'>

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Score',y='Dystopia Residual',data=ds)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Dystopia Residual'>

# %%
i= ds.iloc[:,5:14]
i = ds.columns

for i in i:
    sns.scatterplot(x='Happiness Score',y=i,data=ds)
    plt.show()

# %%
ds.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
dscorr=ds.corr()

# %%
dscorr
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(dscorr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It can be seen from heatmap that Economy, Family,Health,Freedom,Trust,Generosity & Dystopia Residual are positively
# correlated with Happyness score.

# %%
ds.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Considering nominal skew as +/- 0.50

# %%
for i in ds.columns:
    ds[i].astype(str)

# %%
i=ds.iloc[:,4:14]
for i in i:
    sns.distplot(ds[i])
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
ds['Country'] = le.fit_transform(ds['Country'])

# %%
ds['Region'] = le.fit_transform(ds['Region'])

# %%
ds
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
ds1=ds.iloc[:,0:14]
ds2=ds1.astype(float)

# %%
ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    float64
#  1   Region                         158 non-null    float64
#  2   Happiness Rank                 158 non-null    float64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(12)
# ...

# %%
ds2.plot(kind='box',subplots=True,layout=(5,30),figsize=(50,20))
# Out:
# Country                             AxesSubplot(0.125,0.749828;0.021648x0.130172)
# Region                           AxesSubplot(0.150978,0.749828;0.021648x0.130172)
# Happiness Rank                   AxesSubplot(0.176955,0.749828;0.021648x0.130172)
# Happiness Score                  AxesSubplot(0.202933,0.749828;0.021648x0.130172)
# Standard Error                   AxesSubplot(0.228911,0.749828;0.021648x0.130172)
# Economy (GDP per Capita)         AxesSubplot(0.254888,0.749828;0.021648x0.130172)
# Family                           AxesSubplot(0.280866,0.749828;0.021648x0.130172)
# Health (Life Expectancy)         AxesSubplot(0.306844,0.749828;0.021648x0.130172)
# Freedom                          AxesSubplot(0.332821,0.749828;0.021648x0.130172)
# Trust (Government Corruption)    AxesSubplot(0.358799,0.749828;0.021648x0.130172)
# Generosity                       AxesSubplot(0.384777,0.749828;0.021648x0.130172)
# ...

# %% [markdown]
# It can be seen from above box plot that there are outliers in Standard Error, Family,Trust,Generosity and Dystopia Residual

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(ds2))
z
# Out:
# array([[1.23877001, 1.30025593, 1.72099989, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [0.44946522, 1.30025593, 1.69907456, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [0.90989302, 1.30025593, 1.67714922, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [1.26069514, 0.37544095, 1.67742676, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [1.26069514, 0.96511655, 1.69935209, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [1.37032081, 0.96511655, 1.72127743, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
ds_new=ds[(z<3).all(axis=1)]

# %%
ds_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
ds_new.shape
# Out:
# (149, 12)

# %%
ploss=((9/158)*100)
ploss
# Out:
# 5.69620253164557

# %% [markdown]
# Since %age loss after removal of outliers is approx 5%, we can continue to buildour model

# %%
ds_new.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

# %%
x=ds_new.iloc[:,4:14]

# %%
y=ds_new.iloc[:,3]

# %%
x=power_transform(x,method='yeo-johnson')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[-0.95033703,  1.49245411,  1.65888018, ...,  1.81762512,
#          0.65957854,  0.75525527],
#        [ 0.37856182,  1.19406711,  2.009125  , ...,  0.32967609,
#          1.56260401,  1.11116834],
#        [-1.04140135,  1.26661161,  1.73078531, ...,  1.95339954,
#          0.97722591,  0.70649452],
#        ...,
#        [-1.32081011, -1.36521585, -2.08738872, ..., -0.19284338,
#          1.13425805, -0.32711524],
#        [-0.69272644, -1.43304072, -2.01044288, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 2.17876604, -1.93874732, -1.9064101 , ..., -0.14727362,
#         -0.17248609, -0.55359235]])

# %%
lr=LinearRegression()

# %%
best_rstate=0
accu=0
for i in range(30,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu *100} found on random_state {best_rstate}")
# Out:
# Best Accuracy 99.77542531492016 found on random_state 60

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=60)

# %%
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
lr.score(x_train,y_train)
# Out:
# 0.9932932247228524

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.model_selection import GridSearchCV

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls = Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9932931800798861

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
rg=Ridge()
clf=GridSearchCV(rg,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
rg = Ridge(alpha=0.0001,random_state=0)
rg.fit(x_train,y_train)
rg.score(x_train,y_train)
# Out:
# 0.9932932247225414

# %%
pred=ls.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean Absolute Error: ', mean_absolute_error(y_test,pred))
print('Mean Squared Error: ', mean_squared_error(y_test,pred))

print('Root Mean Square Error: ', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Error:
# Mean Absolute Error:  0.048190807334497064
# Mean Squared Error:  0.0030070953272456455
# Root Mean Square Error:  0.05483698867776791

# %%
modelpred=np.array(y_test)

predicted=np.array(lr.predict(x_test)).astype(int)

final=pd.DataFrame({"Original" :modelpred, "Predicted" :predicted },index=range(len(modelpred)))

# %%
final
# Out:
#     Original  Predicted
# 0      6.505          6
# 1      4.252          4
# 2      3.956          3
# 3      4.565          4
# 4      3.904          3
# 5      5.759          5
# 6      5.429          5
# 7      3.989          3
# 8      5.360          5
# 9      7.427          7
# 10     6.295          6
# 11     4.033          4
# 12     5.695          5
# 13     5.890          5
# 14     6.983          6
# 15     6.411          6
# 16     6.302          6
# 17     5.833          5
# 18     6.798          6
# 19     4.077          4
# 20     7.119          7
# 21     6.901          6
# 22     7.522          7
# 23     4.642          4
# 24     5.123          5
# 25     5.975          5
# 26     4.297          4
# 27     4.694          4
# 28     5.192          5
# 29     3.681          3
